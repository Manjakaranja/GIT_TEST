# %%
friends = {
    "person_1" : {
        "name" : input("What is your name ?"),
        "money": input("How much you paid {name}")
    }
    ,
    "person_2" :{
        "name" : input("What is your name ?"),
        "money": input("How much you paid {name}")
    }
    
}

print(friends["person_1"]["name"])
# Out:
# Bob

# %%
for i, friend in enumerate(friends):
    personas = (i, friend)
    print(personas)
# Out:
# (0, 'person_1')
# (1, 'person_2')

# %%
print(friends)
# Out:
# {'person_1': {'name': 'Bob', 'money': '30'}, 'person_2': {'name': 'Lucy', 'money': '20'}}
