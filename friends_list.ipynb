# %%
friends = {
    "person_1" : {
        "name" : input("What is your name ?"),
        "money": input("How much you paid {name}")
    }
    ,
    "person_2" :{
        "name" : input("What is your name ?"),
        "money": input("How much you paid {name}")
    }
    
}

print(friends["person_1"]["name"])
# Out:
# Bob
